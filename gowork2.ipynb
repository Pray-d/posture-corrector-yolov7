# %% [markdown]
# # IMPORT THE DATA

# %%
import pandas as pd
dft=pd.read_csv("C:\\Users\\USER\\Desktop\\feap\\ffalse.csv",sep=';')
dft['label']=0
dft.head()
# Out:
#     xNose   yNose  scoreNose   xNeck    yNeck  scoreNeck  xRShoulder  \
# 0  368.80  371.18    0.95197  364.65  166.690    0.97659      368.06
# 1  368.80  371.18    0.95197  364.65  166.690    0.97659      368.06
# 2  263.37  331.77    0.94037  221.06   69.778    0.98302      218.63
# 3  236.55  370.66    0.91352  292.89  143.440    0.96209      295.34
# 4  364.32  381.48    0.93910  268.91  179.400    0.98565      272.99
#
#    yRShoulder  scoreRShoulder  xRElbow  ...   xLEye   yLEye  scoreLEye  \
# 0     149.520         0.28258   355.29  ...  326.85  415.44    0.56256
# 1     149.520         0.28258   355.29  ...  326.85  415.44    0.56256
# 2      63.055         0.45343   213.48  ...  375.27  218.51    0.89458
# 3     130.600         0.98354   290.06  ...  280.60  356.68    0.55220
# 4     159.920         0.99625   264.63  ...  285.85  397.56    0.15269
#
#     xREar   yREar  scoreREar   xLEar   yLEar  scoreLEar  label
# ...

# %%
df2=pd.read_csv("C:\\Users\\USER\\Desktop\\feap\\ftrue.csv",sep=';')
df2.head()
# Out:
#     xNose   yNose  scoreNose   xNeck    yNeck  scoreNeck  xRShoulder  \
# 0  392.72  465.23    0.95575  484.64  207.530    0.93415      496.46
# 1  302.02  389.56    0.94202  244.38   95.140    0.81777      239.61
# 2  110.40  492.21    0.67507  234.21   87.279    0.96865      231.24
# 3  240.96  565.76    0.93898  185.04  135.670    0.99335      198.52
# 4  161.83  404.48    0.93215  201.14  172.510    0.99632      208.75
#
#    yRShoulder  scoreRShoulder  xRElbow  ...    xLEye   yLEye  scoreLEye  \
# 0     201.300        0.032829   494.26  ...  216.110  276.49    0.97184
# 1      85.177        0.027604   240.45  ...  393.700  336.09    0.70378
# 2      76.653        0.195460   223.28  ...  188.780  494.01    0.86141
# 3     124.410        0.993030   176.39  ...   80.196  415.30    0.97445
# 4     165.040        0.992190   193.40  ...  170.370  418.08    0.96667
#
#     xREar   yREar  scoreREar   xLEar   yLEar  scoreLEar  label
# ...

# %%
import numpy as np
# Concaténer les dataframes
dfp = pd.concat([dft, df2])
df = dfp.sample(frac=1, random_state=42)
#understand more sample §§§§§§§§§
# Écrire le dataframe concaténé dans un nouveau fichier C
df.to_csv('C:\\Users\\USER\\Desktop\\feap\\posture2.csv', index=False)
df
# Out:
#       xNose   yNose  scoreNose   xNeck    yNeck  scoreNeck  xRShoulder  \
# 30   297.75  363.83    0.93630  260.51  194.550    0.98897      261.43
# 126  227.84  319.71    0.93510  352.08  126.730    0.98255      358.85
# 60   115.01  172.77    0.88683  126.64  100.180    0.96249      131.97
# 3    240.96  565.76    0.93898  185.04  135.670    0.99335      198.52
# 114  403.27  421.46    0.95433  463.51  135.440    0.98507      479.44
# ..      ...     ...        ...     ...      ...        ...         ...
# 49   217.48  633.78    0.95052  160.33   82.614    0.99934      176.91
# 71   262.12  349.71    0.94238  243.10  165.220    0.96860      244.44
# 106  391.04  362.05    0.94204  297.33  179.940    0.93155      299.37
# 131  277.49  322.14    0.94275  254.31  198.760    0.99521      261.66
# 102  281.67  244.72    0.92343  377.33  310.740    0.97749      375.31
#
#      yRShoulder  scoreRShoulder  xRElbow  ...    xLEye   yLEye  scoreLEye  \
# ...

# %%
df.isna().sum()
# Out:
# xNose             0
# yNose             0
# scoreNose         0
# xNeck             0
# yNeck             0
# scoreNeck         0
# xRShoulder        0
# yRShoulder        0
# scoreRShoulder    0
# xRElbow           0
# yRElbow           0
# scoreRElbow       0
# xRWrist           0
# yRWrist           0
# scoreRWrist       0
# xLShoulder        0
# yLShoulder        0
# scoreLShoulder    0
# xLElbow           0
# yLElbow           0
# scoreLElbow       0
# xLWrist           0
# yLWrist           0
# scoreLWrist       0
# xRHip             0
# yRHip             0
# scoreRHip         0
# xRKnee            0
# yRKnee            0
# scoreRKnee        0
# xRAnkle           0
# yRAnkle           0
# scoreRAnkle       0
# xLHip             0
# yLHip             0
# scoreLHip         0
# xLKnee            0
# yLKnee            0
# scoreLKnee        0
# xLAnkle           0
# yLAnkle           0
# scoreLAnkle       0
# xREye             0
# yREye             0
# scoreREye         0
# ...

# %%
g = sns.pairplot(df, hue="Outcome")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 g = sns.pairplot(df, hue="Outcome")
#
# NameError: name 'sns' is not defined

# %% [markdown]
# # VISUALIZE DATA EQUILIBRIUM

# %% [markdown]
# The first plot shows pairwise relationships between features, with each point colored by its corresponding label. This can help identify any patterns or relationships between features that may be useful for classification.
#
# The second plot shows a correlation matrix, with higher correlations indicated by brighter colors. This can help identify any multicollinearity issues between features, which could impact the performance of the model.
#
# The third plot shows a histogram of the target variable, which can help visualize the class distribution and identify any imbalances that may need to be addressed.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.countplot(x='label', data=df)
plt.show()

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

axs[0, 0].scatter(df['xLShoulder'], df['yLShoulder'], c=df['label'])
axs[0, 0].set_xlabel('xLShoulder')
axs[0, 0].set_ylabel('yLShoulder')

axs[0, 1].scatter(df['xRShoulder'], df['yRShoulder'], c=df['label'])
axs[0, 1].set_xlabel('xRShoulder')
axs[0, 1].set_ylabel('yRShoulder')

axs[1, 0].scatter(df['xNeck'], df['yNeck'], c=df['label'])
axs[1, 0].set_xlabel('xNeck')
axs[1, 0].set_ylabel('yNeck')

axs[1, 1].scatter(df['xLHip'], df['yLHip'], c=df['label'])
axs[1, 1].set_xlabel('xLHip')
axs[1, 1].set_ylabel('yLHip')

plt.show()

# %% [markdown]
# # SPLITING THE DATA

# %%
X = df.drop('label', axis=1)
y = df['label']

# %%
# split the dataset into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42,stratify=y)
print("training set x size",X_train.shape)
print("training set y size",y_train.shape)
print("testing set x size",X_test.shape)
print("trainign set y size",y_test.shape)
# Out:
# training set x size (194, 54)
# training set y size (194,)
# testing set x size (84, 54)
# trainign set y size (84,)

# %% [markdown]
# # CHOOSING /TRAINING THE MODELS

# %% [markdown]
# # gaussien bernouli nominal

# %% [markdown]
# # bernoulli

# %%
from sklearn.naive_bayes import BernoulliNB 

import pickle
m = BernoulliNB ()

m.fit(X_train,y_train)

# save the model to disk

filename = 'C:\\Users\\USER\\Desktop\\naive_bayes_bernoulli.sav'
pickle.dump(m, open(filename, 'wb'))

# Make predictions on the testing data
y_predA = m.predict(X_test)
# Generate confusion matrix
confusion_mat = confusion_matrix(y_test, y_predA)
print("Confusion Matrix:")
print(confusion_mat)

# Generate classification report
classification_rep = classification_report(y_test, y_predA)
print("Classification Report:")
print(classification_rep)
# Out:
# Confusion Matrix:
# [[42  0]
#  [42  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67        42
#            1       0.00      0.00      0.00        42
#
#     accuracy                           0.50        84
#    macro avg       0.25      0.50      0.33        84
# weighted avg       0.25      0.50      0.33        84
# D:\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# # multinominal

# %%
from sklearn.naive_bayes import MultinomialNB 
m=MultinomialNB()

m.fit(X_train, y_train)

# save the model to disk

filename = 'C:\\Users\\USER\\Desktop\\naive_bayes_multinominal.sav'
pickle.dump(m, open(filename, 'wb'))

# %% [markdown]
# # gaussian

# %%
from sklearn.naive_bayes import GaussianNB 
g=GaussianNB()

g.fit(X_train, y_train)

# save the model to disk

filename = 'C:\\Users\\USER\\Desktop\\gaussien.sav'
pickle.dump(g, open(filename, 'wb'))

# %%
c= 'C:\\Users\\USER\\Desktop\\feap\\gaussien.sav'
pickle.dump(m, open(c, 'wb'))
loaded_model = pickle.load(open(c, 'rb'))
result = loaded_model.score(X_test, y_test)
print(result)
# Out:
# 0.8333333333333334

# %% [markdown]
# # cnn

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, Flatten



# Reshape the input data
#X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
#X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Define the model
model = Sequential()
model.add(Conv1D(32, 3, activation="relu", input_shape=(X_train.shape[1], 1)))
model.add(MaxPooling1D(2))
model.add(Conv1D(64, 3, activation="relu"))
model.add(MaxPooling1D(2))
model.add(Flatten())
model.add(Dense(64, activation="relu"))
model.add(Dense(1, activation="sigmoid"))

# Compile the model
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)


# Generate classification report
classification_rep = classification_report(y_test, y_pred)

# Print the classification report
print(classification_rep)
# Out:
# Epoch 1/10
# 7/7 [==============================] - 5s 110ms/step - loss: 13.5705 - accuracy: 0.5412 - val_loss: 6.1503 - val_accuracy: 0.5000
# Epoch 2/10
# 7/7 [==============================] - 0s 20ms/step - loss: 6.6630 - accuracy: 0.5206 - val_loss: 2.3441 - val_accuracy: 0.5595
# Epoch 3/10
# 7/7 [==============================] - 0s 16ms/step - loss: 2.7206 - accuracy: 0.5825 - val_loss: 3.3765 - val_accuracy: 0.5952
# Epoch 4/10
# 7/7 [==============================] - 0s 15ms/step - loss: 2.4357 - accuracy: 0.5928 - val_loss: 0.8005 - val_accuracy: 0.6667
# Epoch 5/10
# 7/7 [==============================] - 0s 15ms/step - loss: 1.4929 - accuracy: 0.6031 - val_loss: 0.8153 - val_accuracy: 0.5833
# Epoch 6/10
# 7/7 [==============================] - 0s 15ms/step - loss: 1.4201 - accuracy: 0.6392 - val_loss: 2.0233 - val_accuracy: 0.5000
# Epoch 7/10
# ...

# %%
model.save("cnn_model.h5")

# %%
from tensorflow.keras.models import load_model

model = load_model("cnn_model.h5")

# %% [markdown]
# # logistic regression

# %%
#logistic
# import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test= scaler.transform(X_test)

# %%
# standardize the features
#scaler = StandardScaler()
#X_train = scaler.fit_transform(X_train)
#X_test = scaler.transform(X_test)

# create a logistic regression model
lr = LogisticRegression(random_state=42, max_iter=1000)

# tune the hyperparameters using GridSearchCV
params = {'C': np.logspace(-4, 4, 20),
          'penalty': ['l1', 'l2', 'elasticnet'],
          'solver': ['lbfgs', 'liblinear', 'saga']}
grid_search = GridSearchCV(lr, params, cv=5, scoring='accuracy', n_jobs=-1)
grid_search.fit(X_train, y_train)

# use the best model to make predictions on the testing data
best_lr = grid_search.best_estimator_
y_pred = best_lr.predict(X_test)
# Out:
# D:\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 400 fits failed out of a total of 900.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 100 fits failed with the following error:
# Traceback (most recent call last):
#   File "D:\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\anaconda\lib\site-packages\sklearn\linear_model\_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "D:\anaconda\lib\site-packages\sklearn\linear_model\_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ...

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt
# %matplotlib inline
conf_matrix = confusion_matrix(y_test, y_pred)
#plot confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=['wrong', 'right'])
disp.plot()
plt.show()

# %%
# Evaluate the performance of the model
accuracy = accuracy_score(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print the results
print('Accuracy:', accuracy)
print('Classification Report:\n', class_report)
# Out:
# Accuracy: 0.9047619047619048
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.88      0.90        42
#            1       0.89      0.93      0.91        42
#
#     accuracy                           0.90        84
#    macro avg       0.91      0.90      0.90        84
# weighted avg       0.91      0.90      0.90        84

# %%
# evaluate the performance of the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)
print('Accuracy:', accuracy)
print('Confusion Matrix:', conf_matrix)
print('Classification Report:', class_report)
# Out:
# Accuracy: 0.9047619047619048
# Confusion Matrix: [[37  5]
#  [ 3 39]]
# Classification Report:               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.90        42
#            1       0.89      0.93      0.91        42
#
#     accuracy                           0.90        84
#    macro avg       0.91      0.90      0.90        84
# weighted avg       0.91      0.90      0.90        84

# %%
import h5py
with h5py.File('C:\\Users\\USER\\Desktop\\feap\\modelbig3.h5', 'w') as f:
    f.attrs['lr'] = np.string_(repr(best_lr))

# %%
import pickle
filename = 'C:\\Users\\USER\\Desktop\\feap\\\modelbig3.h5'
pickle.dump(best_lr, open(filename, 'wb'))

# %%
c= 'C:\\Users\\USER\\Desktop\\feap\\\modelbig3.h5'
pickle.dump(best_lr, open(c, 'wb'))
loaded_model = pickle.load(open(c, 'rb'))
result = loaded_model.score(X_test, y_test)
print(result)
# Out:
# 0.9047619047619048

# %% [markdown]
# SVM

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report
import pickle

# Create an SVM model
svm_model = SVC(kernel='rbf', C=1.0, random_state=42)

# Train the model
svm_model.fit(X_train, y_train)

# Save the model to disk
filename = 'svm_model.sav'
pickle.dump(svm_model, open(filename, 'wb'))

# Load the saved model
loaded_mo = pickle.load(open(filename, 'rb'))

# Make predictions on the testing data
y_pred = loaded_mo.predict(X_test)

# Generate classification report
classification_rep = classification_report(y_test, y_pred)

# Print the classification report
print(classification_rep)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.83      0.86        42
#            1       0.84      0.90      0.87        42
#
#     accuracy                           0.87        84
#    macro avg       0.87      0.87      0.87        84
# weighted avg       0.87      0.87      0.87        84

# %% [markdown]
# random forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import pickle

# Create a Random Forest model
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model
rf_model.fit(X_train, y_train)

# Save the model to disk
filename = 'random_forest_model.sav'
pickle.dump(rf_model, open(filename, 'wb'))

# Load the saved model
loa= pickle.load(open(filename, 'rb'))

# Make predictions on the testing data
y_pred = loa.predict(X_test)

# Generate classification report
classification_rep = classification_report(y_test, y_pred)

# Print the classification report
print(classification_rep)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.79      0.81        42
#            1       0.80      0.86      0.83        42
#
#     accuracy                           0.82        84
#    macro avg       0.82      0.82      0.82        84
# weighted avg       0.82      0.82      0.82        84

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
#LOGISTIC
#logistic
c= 'C:\\Users\\USER\\Desktop\\feap\\\modelbig2.h5'
loaded_model = pickle.load(open(c, 'rb'))
y_LOG = loaded_model.predict(X_test)
#SVM
# Load the saved model
loaded_mo = pickle.load(open( 'svm_model.sav', 'rb'))
y_SVM = loaded_mo.predict(X_test)
#FOREST 
# Load the saved model
loa= pickle.load(open(filename, 'rb'))
y_FO = loa.predict(X_test)





c_dm = confusion_matrix(y_test, y_LOG)
print ("Matrice de confusion logistic", c_dm)
c_rl = confusion_matrix (y_test, y_SVM )
print ("Matrice de confusion / SVM", c_rl)
c_tr = confusion_matrix (y_test, y_FO)
print ("Matrice de confusion / Random Foret\n", c_tr)

faux_positifs_rl, vrais_positifs_rl, seuil_rl = roc_curve(y_test,y_LOG)
plt.plot(faux_positifs_rl, vrais_positifs_rl, label="Régression Linéaire")
faux_positifs_tr, vrais_positifs_tr, seuil_tr = roc_curve(y_test, y_SVM )
plt.plot(faux_positifs_tr, vrais_positifs_tr, label="SVM")
faux_positifs_dm, vrais_positifs_dm, seuil_dm = roc_curve(y_test, y_FO)
plt.plot(faux_positifs_dm, vrais_positifs_dm, label="Random Forest")
plt.xlabel ("Faux positifs")
plt.ylabel ("Vrais positifs")
plt.legend ()
# Out:
# Matrice de confusion logistic [[38  4]
#  [ 4 38]]
# Matrice de confusion / SVM [[35  7]
#  [ 4 38]]
# Matrice de confusion / Random Foret
#  [[33  9]
#  [ 6 36]]
# D:\anaconda\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # comparaison

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate accuracy, confusion matrix, and classification report for the CNN model




#logistic
c= 'C:\\Users\\USER\\Desktop\\feap\\\modelbig2.h5'
loaded_model = pickle.load(open(c, 'rb'))
result_logistic = loaded_model.score(X_test, y_test)

# Load and evaluate the Gaussian Naive Bayes model
loaded_model_gaussian = pickle.load(open('C:\\Users\\USER\\Desktop\\feap\\gaussien.sav', 'rb'))
accuracy_gaussian = loaded_model_gaussian.score(X_test, y_test)

#svc 

# Load the saved model
loaded_mo = pickle.load(open( 'svm_model.sav', 'rb'))
accuracy_svc = loaded_mo.score(X_test, y_test)

#random forest 
# Save the model to disk
# Save the model to disk
filena = 'random_forest_model.sav'

# Load the saved model
loa= pickle.load(open(filena, 'rb'))
accuracy_forest = loa.score(X_test, y_test)





# Load and evaluate the Bernoulli Naive Bayes model
loaded_model_bernoulli = pickle.load(open('C:\\Users\\USER\\Desktop\\naive_bayes_bernoulli.sav', 'rb'))
accuracy_bernoulli = loaded_model_bernoulli.score(X_test, y_test)

# Load and evaluate the Multinomial Naive Bayes model
loaded_model_multinomial = pickle.load(open('C:\\Users\\USER\\Desktop\\naive_bayes_multinominal.sav', 'rb'))
accuracy_multinomial = loaded_model_multinomial.score(X_test, y_test)

# Create a bar plot to display accuracy for all models
models = ['randforest ','Gaussian', 'Bernoulli', 'binomial','logis-reg ','svc'  ]
accuracies = [ accuracy_forest, accuracy_gaussian, accuracy_bernoulli, accuracy_multinomial,result_logistic,accuracy_svc]

# Define the colors for each bar
colors = [ 'red','blue', 'green', 'orange', 'purple','pink']

plt.bar(models, accuracies, color=colors)
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison')
plt.show()





# Print the accuracy for Gaussian Naive Bayes model
print('Accuracy - Gaussian Naive Bayes:', accuracy_gaussian)

# Print the accuracy for Bernoulli Naive Bayes model
print('Accuracy - Bernoulli Naive Bayes:', accuracy_bernoulli)

# Print the accuracy for Multinomial Naive Bayes model
print('Accuracy - Multinomial Naive Bayes:', accuracy_multinomial)
                                         
# Print the accuracy for logistic
print('Accuracy - logistic regression :', result_logistic)
# Out:
# D:\anaconda\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# D:\anaconda\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but MultinomialNB was fitted with feature names
#   warnings.warn(
# D:\anaconda\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but BernoulliNB was fitted with feature names
#   warnings.warn(
# D:\anaconda\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but MultinomialNB was fitted with feature names
#   warnings.warn(
# Accuracy - Gaussian Naive Bayes: 0.6190476190476191
# Accuracy - Bernoulli Naive Bayes: 0.5
# Accuracy - Multinomial Naive Bayes: 0.6190476190476191
# Accuracy - logistic regression : 0.9047619047619048

# %%
#CNN
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print the results
print('Accuracy:', accuracy)
print('Confusion Matrix:\n', conf_matrix)
print('Classification Report:\n', class_report)
# Out:
# Accuracy: 0.8214285714285714
# Confusion Matrix:
#  [[33  9]
#  [ 6 36]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.79      0.81        42
#            1       0.80      0.86      0.83        42
#
#     accuracy                           0.82        84
#    macro avg       0.82      0.82      0.82        84
# weighted avg       0.82      0.82      0.82        84

# %%
from sklearn.metrics import roc_auc_score
import scikitplot as skplt

y_pred_proba = loaded_model.predict_proba(X_test)
skplt.metrics.plot_precision_recall(y_test, y_pred_proba)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[76], line 2
#       1 from sklearn.metrics import roc_auc_score
# ----> 2 import scikitplot as skplt
#       4 y_pred_proba = loaded_model.predict_proba(X_test)
#       5 skplt.metrics.plot_precision_recall(y_test, y_pred_proba)
#
# ModuleNotFoundError: No module named 'scikitplot'

# %%
import numpy as np
import seaborn as sns


class_probs = loaded_model.predict_proba(X_test)

y0_preds = class_probs[np.where(y_test == 0), 1]
y1_preds = class_probs[np.where(y_test == 1), 1]
sns.distplot(y0_preds, color='blue')
sns.distplot(y1_preds, color='red')
plt.show()
# Out:
# D:\anaconda\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# C:\Users\USER\AppData\Local\Temp\ipykernel_12484\4157839789.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y0_preds, color='blue')
# C:\Users\USER\AppData\Local\Temp\ipykernel_12484\4157839789.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# ...

# %%
import cv2
import numpy as np
import torch
from matplotlib import pyplot as plt
from PIL import Image, ImageDraw, ImageFont
from torchvision import transforms
from models.experimental import attempt_load
from utils.datasets import letterbox
from utils.general import non_max_suppression_kpt
from utils.plots import output_to_keypoint, plot_skeleton_kpts


WEIGHTS = "yolov7-w6-pose.pt"
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
IMAGE_SIZE = 640  # Detection siz

# %%
modeldouaa= attempt_load(WEIGHTS, DEVICE)
# Out:
# Fusing layers...

# %%
import tensorflow as tf
#from tensorflow.keras.models import load_model
#modelt = attempt_load('modelfinale.h5', DEVICE)
#model = load_model('modelfinale.h5')
#modelt = tf.keras.models.load_model('lr.h5')
import cv2
# Define keypoint names
keypoint_names = [
    "Nose",
    "Neck",
    "RShoulder",
    "RElbow",
    "RWrist",
    "LShoulder",
    "LElbow",
    "LWrist",
    "RHip",
    "RKnee",
    "RAnkle",
    "LHip",
    "LKnee",
    "LAnkle",
    "REye",
    "LEye",
    "REar",
    "LEar"
]
cap = cv2.VideoCapture(0) # 0 for default camera
import numpy as np
"scale"==1
while True:
    ret, frame = cap.read()
    image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # convert frame to RGB
    image = letterbox(image, 640, stride=64, auto=True)[0]
    image = image.copy()
    image = transforms.ToTensor()(image)
    image = torch.tensor(np.array([image.numpy()]))
    image = image.float()  # convert image to float precision (cpu)
    output_data, _ =modeldouaa(image)
    output_data = non_max_suppression_kpt(output_data,  # Apply non max suppression
                                          0.25,  # Conf. Threshold.
                                          0.65,  # IoU Threshold.
                                          nc=modeldouaa.yaml['nc'],  # Number of classes.
                                          nkpt=modeldouaa.yaml['nkpt'],  # Number of keypoints.
                                          kpt_label=True)
    d = output_to_keypoint(output_data)
    f=str(d)
    pose_data = f.replace('\n', '')
    pose_data = pose_data.replace(']', ' ', 2)
    pose_data = pose_data.replace('[', ' ', 2)
    lst = [(x) for x in pose_data.split()]
    data_array = lst[4:]
    keypoints_dict = {}
    for i, keypoint in enumerate(keypoint_names):
        keypoints_dict[f"x{keypoint}"] = data_array[i*3]
        keypoints_dict[f"y{keypoint}"] = data_array[i*3 + 1]
        keypoints_dict[f"score{keypoint}"] = data_array[i*3 + 2]
    keypoints_df = pd.DataFrame(keypoints_dict, index=[0])
    x=keypoints_df
    print(x)

    
    
    prediction = loaded_model.predict(x)
    if prediction ==1:
        posture = 'right'
    else:
        lean_forward = keypoints_dict['xLShoulder'] != -1 and keypoints_dict['xRHip'] != -1 \
        and keypoints_dict['xLShoulder'] >= (keypoints_dict['xLHip'] ) \
        and keypoints_dict['xRShoulder'] != -1 and keypoints_dict['xREar'] != -1 \
        and keypoints_dict['xRShoulder'] >= (keypoints_dict['xRHip'])
        slump = keypoints_dict['yNeck'] != -1 and keypoints_dict['yNose'] != -1 \
        and (keypoints_dict['yNose'] >= keypoints_dict['yNeck'] )
        head_drop = keypoints_dict['yLEye'] != -1 and keypoints_dict['yLEar'] != -1 \
        and keypoints_dict['yREye'] != -1 and keypoints_dict['yREar'] != -1 \
        and ((keypoints_dict['yLEye'] ) <= keypoints_dict['yLEar'] \
        or (keypoints_dict['yREye']) <= keypoints_dict['yREar'])
        #if lean_forward or slump or head_drop:
         #   posture = 'Wrong: '
        if lean_forward:
            posture = 'Lean Forward '
        if slump:
            posture = 'Slump '
        if head_drop:
            posture = 'Head Drop'
        else:
            posture = 'Neutral'
    cv2.putText(frame, posture, (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
    cv2.imshow('Posture Classification', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
   
    
cap.release()
cv2.destroyAllWindows()
# Out:
#     xNose   yNose scoreNose   xNeck   yNeck  ...   yREar  scoreREar   xLEar  \
# 0  600.19  471.52    0.9651  525.54  188.86  ...  422.29  0.0072939  280.69
#
#     yLEar scoreLEar
# 0  435.09  0.013257
#
# [1 rows x 54 columns]
#     xNose   yNose scoreNose   xNeck   yNeck  ...   yREar scoreREar   xLEar  \
# 0  167.86  370.07   0.92899  335.02  178.18  ...  478.81  0.086826  369.98
#
#    yLEar scoreLEar
# 0  488.5   0.12669
#
# [1 rows x 54 columns]
#     xNose   yNose scoreNose   xNeck   yNeck  ...   yREar scoreREar   xLEar  \
# 0  109.62  320.89   0.90618  359.21  207.41  ...  489.59   0.13493  339.22
#
#     yLEar scoreLEar
# 0  492.84   0.15874
#
# [1 rows x 54 columns]
#     xNose   yNose scoreNose   xNeck   yNeck  ...   yREar scoreREar   xLEar  \
# 0  141.07  324.23   0.93083  356.87  206.15  ...  496.05   0.10619  349.15
#
#     yLEar scoreLEar
# 0  501.21   0.18969
#
# [1 rows x 54 columns]
#     xNose   yNose scoreNose   xNeck   yNeck  ...   yREar scoreREar   xLEar  \
# ...

# %%
import tensorflow as tf
#from tensorflow.keras.models import load_model
#modelt = attempt_load('modelfinale.h5', DEVICE)
#model = load_model('modelfinale.h5')
#modelt = tf.keras.models.load_model('lr.h5')
import cv2
# Define keypoint names
keypoint_names = [
    "Nose",
    "Neck",
    "RShoulder",
    "RElbow",
    "RWrist",
    "LShoulder",
    "LElbow",
    "LWrist",
    "RHip",
    "RKnee",
    "RAnkle",
    "LHip",
    "LKnee",
    "LAnkle",
    "REye",
    "LEye",
    "REar",
    "LEar"
]
cap = cv2.VideoCapture(0) # 0 for default camera
import numpy as np
"scale"==1
while True:
    ret, frame = cap.read()
    image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # convert frame to RGB
    image = letterbox(image, 640, stride=64, auto=True)[0]
    image = image.copy()
    image = transforms.ToTensor()(image)
    image = torch.tensor(np.array([image.numpy()]))
    image = image.float()  # convert image to float precision (cpu)
    output_data, _ =modeldouaa(image)
    output_data = non_max_suppression_kpt(output_data,  # Apply non max suppression
                                          0.25,  # Conf. Threshold.
                                          0.65,  # IoU Threshold.
                                          nc=modeldouaa.yaml['nc'],  # Number of classes.
                                          nkpt=modeldouaa.yaml['nkpt'],  # Number of keypoints.
                                          kpt_label=True)
    d = output_to_keypoint(output_data)
    f=str(d)
    pose_data = f.replace('\n', '')
    pose_data = pose_data.replace(']', ' ', 2)
    pose_data = pose_data.replace('[', ' ', 2)
    lst = [(x) for x in pose_data.split()]
    data_array = lst[4:]
    keypoints_dict = {}
    for i, keypoint in enumerate(keypoint_names):
        keypoints_dict[f"x{keypoint}"] = data_array[i*3]
        keypoints_dict[f"y{keypoint}"] = data_array[i*3 + 1]
        keypoints_dict[f"score{keypoint}"] = data_array[i*3 + 2]
    keypoints_df = pd.DataFrame(keypoints_dict, index=[0])
    x=keypoints_df
    print(x)

    
    
    prediction = loaded_model.predict(x)
    if prediction ==1:
        posture = 'right'
    else:
        lean_back =(keypoints_dict['xRHip'] <= keypoints_dict['xRShoulder']and keypoints_dict['yRHip'] <= keypoints_dict['yRShoulder'] ) or( keypoints_dict['xLShoulder'] >= keypoints_dict['xLHip'] and keypoints_dict['yLShoulder'] >= keypoints_dict['yLHip'] ) 
        
        
        #lean_back = (keypoints_dict['xREar'] >= keypoints_dict['xRShoulder'] ) or( keypoints_dict['xLEar'] >= keypoints_dict['xLShoulder'] ) 
        #lean_back =(keypoints_dict['yRHip'] >= keypoints_dict['yRShoulder'] ) or( keypoints_dict['yLShoulder'] <= keypoints_dict['yLHip']  )   
        #lean_back =(keypoints_dict['xRHip'] >= keypoints_dict['xRShoulder']and keypoints_dict['yREye'] <= keypoints_dict['yREar'] ) or( keypoints_dict['xLShoulder'] >= keypoints_dict['xLHip'] and keypoints_dict['yLEye'] <= keypoints_dict['yLEar'] ) 
        slump =(keypoints_dict['xRHip'] <= keypoints_dict['xRShoulder']and keypoints_dict['yREye'] <= keypoints_dict['yREar'] ) or( keypoints_dict['xLShoulder'] >= keypoints_dict['xLHip'] and keypoints_dict['yLEye'] >= keypoints_dict['yLEar'] )   
        head_drop = keypoints_dict['yLEye'] <= keypoints_dict['yNeck'] or keypoints_dict['yREye'] <= keypoints_dict['yNeck']
        
        #if lean_forward or slump or head_drop:
         #   posture = 'Wrong: '
        if lean_back:
            posture = 'Lean Backward'
        if slump:
            posture = 'Slump '
        if head_drop:
            posture = 'Head Drop'
        
    cv2.putText(frame, posture, (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
    cv2.imshow('Posture Classification', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
   
    
cap.release()
cv2.destroyAllWindows()
# Out:
#     xNose   yNose scoreNose   xNeck   yNeck  ...   yREar scoreREar   xLEar  \
# 0  481.36  460.44   0.94163  287.35  259.81  ...  427.65  0.013176  185.72
#
#     yLEar scoreLEar
# 0  433.88  0.010395
#
# [1 rows x 54 columns]
#     xNose   yNose scoreNose   xNeck   yNeck  ...   yREar scoreREar   xLEar  \
# 0  483.05  472.17   0.94447  260.52  232.89  ...  426.32  0.012313  188.84
#
#     yLEar  scoreLEar
# 0  434.25  0.0098306
#
# [1 rows x 54 columns]
#     xNose   yNose scoreNose   xNeck   yNeck  ...   yREar  scoreREar   xLEar  \
# 0  594.15  471.51   0.90937  424.76  21.262  ...  427.27  0.0043352  275.06
#
#     yLEar  scoreLEar
# 0  435.52  0.0051356
#
# [1 rows x 54 columns]
#    xNose   yNose scoreNose   xNeck   yNeck  ...   yREar scoreREar  xLEar  \
# 0  279.5  309.14   0.84625  405.28  246.48  ...  493.77  0.059635  270.4
#
#     yLEar scoreLEar
# 0  488.43  0.048854
#
# [1 rows x 54 columns]
#     xNose   yNose scoreNose   xNeck   yNeck  ...   yREar scoreREar   xLEar  \
# ...

# %%
import tensorflow as tf
#from tensorflow.keras.models import load_model
#modelt = attempt_load('modelfinale.h5', DEVICE)
#model = load_model('modelfinale.h5')
#modelt = tf.keras.models.load_model('lr.h5')
import cv2
# Define keypoint names
keypoint_names = [
    "Nose",
    "Neck",
    "RShoulder",
    "RElbow",
    "RWrist",
    "LShoulder",
    "LElbow",
    "LWrist",
    "RHip",
    "RKnee",
    "RAnkle",
    "LHip",
    "LKnee",
    "LAnkle",
    "REye",
    "LEye",
    "REar",
    "LEar"
]
cap = cv2.VideoCapture(0) # 0 for default camera
import numpy as np
"scale"==1
while True:
    ret, frame = cap.read()
    image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # convert frame to RGB
    image = letterbox(image, 640, stride=64, auto=True)[0]
    image = image.copy()
    image = transforms.ToTensor()(image)
    image = torch.tensor(np.array([image.numpy()]))
    image = image.float()  # convert image to float precision (cpu)
    output_data, _ =modeldouaa(image)
    output_data = non_max_suppression_kpt(output_data,  # Apply non max suppression
                                          0.25,  # Conf. Threshold.
                                          0.65,  # IoU Threshold.
                                          nc=modeldouaa.yaml['nc'],  # Number of classes.
                                          nkpt=modeldouaa.yaml['nkpt'],  # Number of keypoints.
                                          kpt_label=True)
    d = output_to_keypoint(output_data)
    f=str(d)
    pose_data = f.replace('\n', '')
    pose_data = pose_data.replace(']', ' ', 2)
    pose_data = pose_data.replace('[', ' ', 2)
    lst = [(x) for x in pose_data.split()]
    data_array = lst[4:]
    keypoints_dict = {}
    for i, keypoint in enumerate(keypoint_names):
        keypoints_dict[f"x{keypoint}"] = data_array[i*3]
        keypoints_dict[f"y{keypoint}"] = data_array[i*3 + 1]
        keypoints_dict[f"score{keypoint}"] = data_array[i*3 + 2]
    keypoints_df = pd.DataFrame(keypoints_dict, index=[0])
    x=keypoints_df
    print(x)

    
    
    prediction = loaded_model.predict(x)
    if prediction ==1:
        posture = 'right'
    else:
       
        #if keypoints_dict['xLShoulder'] >= keypoints_dict['xLEar'] or keypoints_dict['yRShoulder'] >= keypoints_dict['yREar']:
         #       posture = 'Lean Forward '
        #if keypoints_dict['xRShoulder'] >= keypoints_dict['xREar'] or keypoints_dict['yRShoulder'] >= keypoints_dict['yREar']:
          #  posture = 'Lean Forward '
        
        if (keypoints_dict['xRHip'] <= keypoints_dict['xRShoulder'] ) or( keypoints_dict['xLShoulder'] >= keypoints_dict['xLHip'] ) :
            posture = 'leaning back '
        if (keypoints_dict['xREar'] >= keypoints_dict['xRShoulder']and keypoints_dict['yREye'] >= keypoints_dict['yREar'] ) or( keypoints_dict['xLShoulder'] >= keypoints_dict['xLEar'] and keypoints_dict['yLEye'] >= keypoints_dict['yLEar'] ) :
            posture = 'slump '
        if keypoints_dict['yLEye'] <= keypoints_dict['yNeck'] or keypoints_dict['yREye'] <= keypoints_dict['yNeck']:
            posture = 'Head Drop'
    cv2.putText(frame, posture, (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
    cv2.imshow('Posture Classification', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
   
    
cap.release()
cv2.destroyAllWindows()
# Out:
#     xNose   yNose scoreNose   xNeck   yNeck  ...  yREar scoreREar   xLEar  \
# 0  486.33  422.24   0.93543  481.18  366.99  ...  424.2  0.010897  394.68
#
#     yLEar scoreLEar
# 0  443.12  0.012855
#
# [1 rows x 54 columns]
#     xNose   yNose scoreNose   xNeck   yNeck  ...   yREar scoreREar   xLEar  \
# 0  457.37  397.52   0.92367  462.55  348.39  ...  425.42  0.011897  387.29
#
#     yLEar scoreLEar
# 0  436.97  0.013203
#
# [1 rows x 54 columns]
#     xNose   yNose scoreNose   xNeck   yNeck  ...   yREar scoreREar  xLEar  \
# 0  350.99  280.31   0.83827  408.94  326.53  ...  451.95  0.023726  325.3
#
#     yLEar scoreLEar
# 0  453.54  0.031051
#
# [1 rows x 54 columns]
#     xNose   yNose scoreNose   xNeck   yNeck  ...   yREar scoreREar   xLEar  \
# 0  212.67  217.49   0.67647  627.37  425.83  ...  476.67   0.01963  504.03
#
#     yLEar scoreLEar
# 0  477.96  0.036085
#
# [1 rows x 54 columns]
#     xNose   yNose scoreNose   xNeck   yNeck  ...   yREar scoreREar   xLEar  \
# ...

# %%
import cv2
import numpy as np

# Define keypoint names
keypoint_names = [
    "Nose",
    "Neck",
    "RShoulder",
    "RElbow",
    "RWrist",
    "LShoulder",
    "LElbow",
    "LWrist",
    "RHip",
    "RKnee",
    "RAnkle",
    "LHip",
    "LKnee",
    "LAnkle",
    "REye",
    "LEye",
    "REar",
    "LEar"
]

cap = cv2.VideoCapture(0)  # 0 for default camera

while True:
    ret, frame = cap.read()
    image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # convert frame to RGB
    image = letterbox(image, 640, stride=64, auto=True)[0]
    image = image.copy()
    image = transforms.ToTensor()(image)
    image = torch.tensor(np.array([image.numpy()]))
    image = image.float()  # convert image to float precision (cpu)
    output_data, _ = modeldouaa(image)
    output_data = non_max_suppression_kpt(output_data,  # Apply non max suppression
                                          0.25,  # Conf. Threshold.
                                          0.65,  # IoU Threshold.
                                          nc=modeldouaa.yaml['nc'],  # Number of classes.
                                          nkpt=modeldouaa.yaml['nkpt'],  # Number of keypoints.
                                          kpt_label=True)
    d = output_to_keypoint(output_data)
    f = str(d)
    pose_data = f.replace('\n', '')
    pose_data = pose_data.replace(']', ' ', 2)
    pose_data = pose_data.replace('[', ' ', 2)
    lst = [(x) for x in pose_data.split()]
    data_array = lst[4:]
    keypoints_dict = {}
    for i, keypoint in enumerate(keypoint_names):
        keypoints_dict[f"x{keypoint}"] = data_array[i*3]
        keypoints_dict[f"y{keypoint}"] = data_array[i*3 + 1]
        keypoints_dict[f"score{keypoint}"] = data_array[i*3 + 2]
    keypoints_df = pd.DataFrame(keypoints_dict, index=[0])
    x = keypoints_df

    prediction = loaded_model.predict(x)
    if prediction == 1:
        posture = 'right'
    else:
         if keypoints_dict['xLShoulder'] >= keypoints_dict['xLEar'] or keypoints_dict['yRShoulder'] >= keypoints_dict['yREar']:
                posture = 'Lean Forward '
         if keypoints_dict['xRShoulder'] >= keypoints_dict['xREar'] or keypoints_dict['yRShoulder'] >= keypoints_dict['yREar']:
            posture = 'Lean Forward '
         if (keypoints_dict['xRHip'] <= keypoints_dict['xRShoulder']and keypoints_dict['yREye'] <= keypoints_dict['yREar'] ) or( keypoints_dict['xLShoulder'] >= keypoints_dict['xLHip'] and keypoints_dict['yLEye'] <= keypoints_dict['yLEar'] ) :
            posture = 'leaning back '
         if (keypoints_dict['xRHip'] >= keypoints_dict['xRShoulder']and keypoints_dict['yREye'] >= keypoints_dict['yREar'] ) or( keypoints_dict['xLShoulder'] >= keypoints_dict['xLHip'] and keypoints_dict['yLEye'] >= keypoints_dict['yLEar'] ) :
            posture = 'slump '
         if keypoints_dict['yLEye'] <= keypoints_dict['yNeck'] or keypoints_dict['yREye'] <= keypoints_dict['yNeck']:
            posture = 'Head Drop'
   
   
   

    
    cv2.putText(frame, posture, (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
    cv2.imshow('Posture Classification', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[104], line 52
#      50 keypoints_dict = {}
#      51 for i, keypoint in enumerate(keypoint_names):
# ---> 52     keypoints_dict[f"x{keypoint}"] = data_array[i*3]
#      53     keypoints_dict[f"y{keypoint}"] = data_array[i*3 + 1]
#      54     keypoints_dict[f"score{keypoint}"] = data_array[i*3 + 2]
#
# IndexError: list index out of range

# %%
import cv2
import numpy as np

# Define keypoint names
keypoint_names = [
    "Nose",
    "Neck",
    "RShoulder",
    "RElbow",
    "RWrist",
    "LShoulder",
    "LElbow",
    "LWrist",
    "RHip",
    "RKnee",
    "RAnkle",
    "LHip",
    "LKnee",
    "LAnkle",
    "REye",
    "LEye",
    "REar",
    "LEar"
]

image_path = "C:\\Users\\USER\\Desktop\\redaction\\15.jpg"  # Path to your image
import matplotlib.image as mpimg
# Read the image file
imageA = mpimg.imread(image_path)

# Load and process the image
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image = letterbox(image, 640, stride=64, auto=True)[0]
image = image.copy()
image = transforms.ToTensor()(image)
image = torch.tensor(np.array([image.numpy()]))
image = image.float()  # convert image to float precision (cpu)


output_data, _ = modeldouaa(image)
  
output_data = non_max_suppression_kpt(output_data,  # Apply non max suppression
                                      0.25,  # Conf. Threshold.
                                      0.65,  # IoU Threshold.
                                      nc= modeldouaa.yaml['nc'],  # Number of classes.
                                      nkpt= modeldouaa.yaml['nkpt'],  # Number of keypoints.
                                      kpt_label=True)

d = output_to_keypoint(output_data)
f = str(d)
pose_data = f.replace('\n', '')
pose_data = pose_data.replace(']', ' ', 2)
pose_data = pose_data.replace('[', ' ', 2)
lst = [(x) for x in pose_data.split()]
data_array = lst[4:]
keypoints_dict = {}
for i, keypoint in enumerate(keypoint_names):
    keypoints_dict[f"x{keypoint}"] = data_array[i*3]
    keypoints_dict[f"y{keypoint}"] = data_array[i*3 + 1]
    keypoints_dict[f"score{keypoint}"] = data_array[i*3 + 2]

keypoints_df = pd.DataFrame(keypoints_dict, index=[0])
x = keypoints_df

prediction = loaded_model.predict(x)
if prediction == 1:
    posture = 'right'
else:
    posture = 'unkown wrong posture'
    if keypoints_dict['xLShoulder'] >= keypoints_dict['xLEar'] or keypoints_dict['yRShoulder'] >= keypoints_dict['yREar']:
        posture = 'Lean Forward '
   # if keypoints_dict['xRShoulder'] >= keypoints_dict['xREar'] or keypoints_dict['yRShoulder'] >= keypoints_dict['yREar']:
      #  posture = 'Lean Forward '
    #if (keypoints_dict['xRHip'] >= keypoints_dict['xRShoulder']and keypoints_dict['yREye'] >= keypoints_dict['yREar'] ) or( keypoints_dict['xLShoulder'] >= keypoints_dict['xLHip'] and keypoints_dict['yLEye'] >= keypoints_dict['yLEar'] ) :
    #    posture = 'leaning back '
    if (keypoints_dict['xRHip'] >= keypoints_dict['xRShoulder']and keypoints_dict['yREye'] >= keypoints_dict['yREar'] ) or( keypoints_dict['xLShoulder'] >= keypoints_dict['xLHip'] and keypoints_dict['yLEye'] >= keypoints_dict['yLEar'] ) :
        posture = 'slump '
    if (keypoints_dict['xRHip'] <= keypoints_dict['xRShoulder']and keypoints_dict['yREye'] <= keypoints_dict['yREar'] ) or( keypoints_dict['xLShoulder'] <= keypoints_dict['xLHip'] and keypoints_dict['yLEye'] <= keypoints_dict['yLEar'] ) :
        posture = 'leaning back' 
    if keypoints_dict['yLEye'] <= keypoints_dict['yNeck'] or keypoints_dict['yREye'] <= keypoints_dict['yNeck']:
        posture = 'Head Drop'



import matplotlib.pyplot as plt


# Assuming you have an image named "image" to display
plt.imshow(imageA)

plt.axis('off')  # Turn off the axis labels
# Add text to the image
plt.text(10, 50,  posture, color='red', fontsize=12)

plt.show()

cv2.waitKey(0)
cv2.destroyAllWindows()
